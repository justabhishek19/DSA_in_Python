# %%
from collections import deque

# %%
stack = deque()

# %%
stack
# Out:
# deque([])

# %%
len(stack)
# Out:
# 0

# %%
len(stack) == 0
# Out:
# True

# %%
print(stack)
# Out:
# deque([])

# %%
stack.append(20)  #push

# %%
stack
# Out:
# deque([20])

# %%
stack.append(15)
stack.append(35)
stack.append(10)

# %%
stack
# Out:
# deque([20, 15, 35, 10])

# %%
stack.pop()    #pop
# Out:
# 10

# %%
stack
# Out:
# deque([20, 15, 35])

# %%
stack[-1]        #peek
# Out:
# 35
