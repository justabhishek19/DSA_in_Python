# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

# %%
class CSLL:
    def __init__(self):
        self.head = None
        self.length = 0

    def is_empty(self):
        return self.head is None

    def display(self):
        if self.is_empty():
            print("Empty List")

        else:
            current = self.head
            while True:
                print(ccurrent.data, end=" ")
                current = current.next
                if current == self.head:
                    break
            print()

    def insert_at_beginning(self,value):
        node = Node(value)
        if self.is_empty():
            self.head = node
            self.head.next = node
        else:
            current = self.head
            while current.next != self.head:
                current = current.next
            node.next = self.head
            current.next = node
            self.head = node
        self.length += 1
        self.display()

    def insert_at_end(self,value):
        node = Node(value)
        if self.is_empty():
            self.head = node
            self.head.next = node
        else:
            current = self.head
            while current.next != self.head:
                current = current.next
            node.next = self.head
            current.next = node
        self.length += 1
        self.display()

    def insert_at_index(self,pos,value):
        if pos == 0:
            self.insert_at_beginning(value)
            
        elif pos == self.length:
            self.insert_at_end(value)

        elif pos < 0 or pos > self.length:
            print("Invalid Index")
            
        else:
            node = Node(value)
            current = self.head
            for _ in range(pos-1):
                current = current.next
            node.next = current.next
            current.next = node
            self.display()
            self.length += 1

    def search(self,key):
        if self.is_empty():
            print("List is Empty")
        else:
            current = self.head
            index = 0
            while True:
                if current.data == key:
                    return index
                index += 1
                
                current = current.next
                if current == self.head:
                    return -1

    def delete_at_beginning(self):
        if self.is_empty():
            print("List is Empty")
            return
        else:
            current = self.head
            while current.next != self.head:
                current = current.next
            current.next = self.head.next
            self.head.next = None
            self.head = current.next
        self.display()
        self.length -= 1
        

    def delete_at_end(self):
        if self.is_empty():
            print("List is Empty")
            return
        elif self.length == 1:
            self.head = None
        else:
            current = self.head
            while current.next.next != self.head:
                current = current.next
            current.next.next = None
            current.next = self.head
        self.display()
        self.length -= 1

    def delete_at_indx(self,pos):
        if pos == 0:
            self.delete_at_beginning()
            
        elif pos == self.length-1:
            self.delete_at_end()

        elif pos < 0 or pos >= self.length:
            print("Invalid Index")
            
        else:
            current = self.head
            for _ in range(pos-1):
                current = current.next
            temp = current.next.next
            current.next.next = None
            current.next = temp
            self.display()
            self.length -= 1

# %%
csll = CSLL()

# %%
csll.length
# Out:
# 0

# %%
csll.display()
# Out:
# Empty List

# %%
csll.search(42)
# Out:
# List is Empty

# %%
csll.delete_at_beginning()
# Out:
# List is Empty

# %%
csll.insert_at_end(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 csll.insert_at_end(5)
#
# Cell In[2], line 49, in CSLL.insert_at_end(self, value)
#      47     current.next = node
#      48 self.length += 1
# ---> 49 self.display()
#
# Cell In[2], line 16, in CSLL.display(self)
#      14 current = self.head
#      15 while True:
# ---> 16     print(ccurrent.data, end=" ")
#      17     current = current.next
#      18     if current == self.head:
#
# NameError: name 'ccurrent' is not defined

# %%
csll.display()

# %%
csll.delete_at_beginning()

# %%
csll.display()

# %%
csll.insert_at_beginning(10)

# %%
csll.is_empty()

# %%
csll.insert_at_beginning(20)

# %%
csll.length

# %%
csll.insert_at_beginning(30)
csll.insert_at_beginning(40)
csll.insert_at_beginning(50)

# %%
csll.length

# %%
csll.insert_at_end(60)

# %%
csll.length

# %%
csll.insert_at_end(70)
csll.insert_at_end(80)

# %%
csll.insert_at_index(0,77)

# %%
csll.length

# %%
csll.insert_at_index(10,999)

# %%
csll.length

# %%
csll.insert_at_index(12,100)

# %%
csll.insert_at_index(1,98)

# %%
csll.length

# %%
csll.search(42)

# %%
csll.search(20)

# %%
csll.search(999)

# %%
csll.search(77)

# %%
csll.search(5)

# %%
csll.display()

# %%
csll.delete_at_beginning()

# %%
csll.length

# %%
csll.delete_at_beginning()
csll.delete_at_beginning()

# %%
csll.length

# %%
csll.display()

# %%
csll.delete_at_end()

# %%
csll.delete_at_end()

# %%
csll.delete_at_indx(2)

# %%
csll.delete_at_indx(0)

# %%
csll.delete_at_indx(2)
