# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None

# %%
class DLL:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def is_empty(self):
        if self.head==None:
            return True

    def display_forward(self):
        if self.is_empty():
            print('List is Empty')
        else:
            current = self.head
            while current:
                print(current.data, end =" <--> " if current.next else '\n')
                current = current.next
            
    def display_backward(self):
        if self.is_empty():
            print('List is Empty')
        else:
            current = self.tail
            while current:
                print(current.data, end =" <--> " if current.prev else '\n')
                current = current.prev

    def insert_at_beginning(self,value):
        node = Node(value)
        
        if not self.head:
            self.head = node
            self.tail = node
        else:
            node.next = self.head
            self.head.prev = node
            self.head = node
        self.length += 1
        self.display_forward()

    def insert_at_end(self,value):
        node = Node(value)
        
        if not self.head:
            self.head = node
            self.tail = node
        else:
            self.tail.next = node
            node.prev = self.tail
            self.tail = node
        self.length += 1
        self.display_forward()

    def insert_at_indx(self,pos,value):
        if pos == 0:
            self.insert_at_beginning(value)
        elif pos == self.length:
            self.insert_at_end(value)
        elif pos<0 or pos > self.length:
            print("INVALID INDEX")
        else:
            node = Node(value)
            current = self.head
            for _ in range(pos-1):
                current = current.next
            node.next = current.next
            current.next.prev = node
            current.next = node
            node.prev = current
            self.length += 1
            self.display_forward()

    def search(self,key):
        if not self.head:
            print("List is Empty")
            return
        else:
            current = self.head
            indx = 0
            while current:
                if current.data == key:
                    print(indx)
                    return
                current = current.next
                indx += 1
        return -1

    def delete_at_beginning(self):
        if self.is_empty():
            print("Can't Delete, List is Empty")
            return
        elif self.length == 1:
            self.head = None
            self.tail = None
        else:
            temp = self.head
            self.head = temp.next
            self.head.prev = None
            temp.next = None
        self.length -= 1
        self.display_forward()

# %%
dll = DLL()

# %%
dll.display_forward()
# Out:
# List is Empty

# %%
dll.search(90)
# Out:
# List is Empty

# %%
dll.display_backward()
# Out:
# List is Empty

# %%
dll.length
# Out:
# 0

# %%
dll.is_empty()
# Out:
# True

# %%
dll.insert_at_beginning(20)
# Out:
# 20

# %%
dll.insert_at_beginning(10)
# Out:
# 10 <--> 20

# %%
dll.insert_at_beginning(30)
# Out:
# 30 <--> 10 <--> 20

# %%
dll.insert_at_beginning(40)
dll.insert_at_beginning(50)
dll.insert_at_beginning(60)
# Out:
# 40 <--> 30 <--> 10 <--> 20
# 50 <--> 40 <--> 30 <--> 10 <--> 20
# 60 <--> 50 <--> 40 <--> 30 <--> 10 <--> 20

# %%
dll.display_backward()
# Out:
# 20 <--> 10 <--> 30 <--> 40 <--> 50 <--> 60

# %%
dll.insert_at_end(1)
# Out:
# 60 <--> 50 <--> 40 <--> 30 <--> 10 <--> 20 <--> 1

# %%
dll.insert_at_end(2)
dll.insert_at_end(3)
dll.insert_at_end(4)
dll.insert_at_end(5)
# Out:
# 60 <--> 50 <--> 40 <--> 30 <--> 10 <--> 20 <--> 1 <--> 2
# 60 <--> 50 <--> 40 <--> 30 <--> 10 <--> 20 <--> 1 <--> 2 <--> 3
# 60 <--> 50 <--> 40 <--> 30 <--> 10 <--> 20 <--> 1 <--> 2 <--> 3 <--> 4
# 60 <--> 50 <--> 40 <--> 30 <--> 10 <--> 20 <--> 1 <--> 2 <--> 3 <--> 4 <--> 5

# %%
dll.display_backward()
# Out:
# 5 <--> 4 <--> 3 <--> 2 <--> 1 <--> 20 <--> 10 <--> 30 <--> 40 <--> 50 <--> 60

# %%
dll.insert_at_indx(0,70)
# Out:
# 70 <--> 60 <--> 50 <--> 40 <--> 30 <--> 10 <--> 20 <--> 1 <--> 2 <--> 3 <--> 4 <--> 5

# %%
dll.insert_at_indx(12,6)
# Out:
# 70 <--> 60 <--> 50 <--> 40 <--> 30 <--> 10 <--> 20 <--> 1 <--> 2 <--> 3 <--> 4 <--> 5 <--> 6

# %%
dll.insert_at_indx(5,99)
# Out:
# 70 <--> 60 <--> 50 <--> 40 <--> 30 <--> 99 <--> 10 <--> 20 <--> 1 <--> 2 <--> 3 <--> 4 <--> 5 <--> 6

# %%
dll.length
# Out:
# 14

# %%
dll.insert_at_indx(15,80)
# Out:
# INVALID INDEX

# %%
dll.search(60)
# Out:
# 1

# %%
dll.search(4)
# Out:
# 11

# %%
dll.search(6)
# Out:
# 13

# %%
dll.search(70)
# Out:
# 0

# %%
dll.search(88)
# Out:
# -1

# %%
dll.delete_at_beginning()
# Out:
# 60 <--> 50 <--> 40 <--> 30 <--> 99 <--> 10 <--> 20 <--> 1 <--> 2 <--> 3 <--> 4 <--> 5 <--> 6

# %%
dll.delete_at_beginning()
# Out:
# 50 <--> 40 <--> 30 <--> 99 <--> 10 <--> 20 <--> 1 <--> 2 <--> 3 <--> 4 <--> 5 <--> 6

# %%
dll.delete_at_beginning()
# Out:
# 40 <--> 30 <--> 99 <--> 10 <--> 20 <--> 1 <--> 2 <--> 3 <--> 4 <--> 5 <--> 6
